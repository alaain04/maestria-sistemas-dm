# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer, KafkaConsumer
import pandas as pd

# %%
#Constants
kafka_server = 'localhost:9092'
topic = 'orders-topic'

# %%
# Cargamos todos los csv en df diferentes
olist_orders = pd.read_csv('../dataset/olist_orders_dataset.csv')
olist_products = pd.read_csv('../dataset/olist_products_dataset.csv')
olist_items = pd.read_csv('../dataset/olist_order_items_dataset.csv')
olist_customers = pd.read_csv('../dataset/olist_customers_dataset.csv')
olist_payments = pd.read_csv('../dataset/olist_order_payments_dataset.csv')
olist_sellers = pd.read_csv('../dataset/olist_sellers_dataset.csv')
olist_geolocation = pd.read_csv('../dataset/olist_geolocation_dataset.csv')
olist_reviews = pd.read_csv('../dataset/olist_order_reviews_dataset.csv')
olist_product_category_name = pd.read_csv('../dataset/product_category_name_translation.csv')

# Mergeamos los df anteriores en uno solo
all_data = olist_orders.merge(olist_items, on='order_id', how='left')
all_data = all_data.merge(olist_payments, on='order_id', how='inner')
all_data = all_data.merge(olist_reviews, on='order_id', how='inner')
all_data = all_data.merge(olist_products, on='product_id', how='inner')
all_data = all_data.merge(olist_customers, on='customer_id', how='inner')
all_data = all_data.merge(olist_sellers, on='seller_id', how='inner')
all_data = all_data.merge(olist_product_category_name,on='product_category_name',how='inner')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4aae18645e53> in <module>
#       1 # Cargamos todos los csv en df diferentes
# ----> 2 olist_orders = pd.read_csv('../dataset/olist_orders_dataset.csv')
#       3 olist_products = pd.read_csv('../dataset/olist_products_dataset.csv')
#       4 olist_items = pd.read_csv('../dataset/olist_order_items_dataset.csv')
#       5 olist_customers = pd.read_csv('../dataset/olist_customers_dataset.csv')
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataset/olist_orders_dataset.csv'

# %%
all_data.to_json()

# %%
try:
    consumer = KafkaConsumer(group_id='test', bootstrap_servers=['localhost:9092'])
    topics = consumer.topics()
    if not topics: 
        print("aca si")
except:
    print('asas')
    sleep()
    #raise RuntimeError()
# Out:
# asas

# %%
producer = KafkaProducer(
    bootstrap_servers=[kafka_server],
    value_serializer=lambda x: dumps(x).encode('utf-8')
)

for index, row in all_data.iterrows():
    print("order_id:", row[0])
    data = row.to_json()    
    producer.send(topic, value=data)
    sleep(0.5)
# Out:
# Iteration e481f51cbdc54678b7cc49136f2d6af7
# Iteration e481f51cbdc54678b7cc49136f2d6af7
# Iteration e481f51cbdc54678b7cc49136f2d6af7
# Iteration 128e10d95713541c87cd1a2e48201934
# Iteration 0e7e841ddf8f8f2de2bad69267ecfbcf
# Iteration bfc39df4f36c3693ff3b63fcbea9e90a
# Iteration 5f49f31e537f8f1a496454b48edbe34d
# Iteration 1fa40f202d5d233b6491e976c557b822
# Iteration 41c045db2d1876be9f05cf4a787693b2
# Iteration a60241fca336b3f14485dff30a172cab
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-6890d28b49b5> in <module>
#       8     data = row.to_json()
#       9     producer.send(topic, value=data)
# ---> 10     sleep(0.5)
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python
# coding: utf-8
from kafka import KafkaConsumer
from json import loads
from time import sleep
import pandas as pd

#Constants
kafka_server = 'localhost:9092'
topic = 'orders-topic'

def run_consumer():
    consumer = KafkaConsumer(
                            topic, 
                            bootstrap_servers=[kafka_server],
                            auto_offset_reset='earliest',
                            enable_auto_commit=True,
                            group_id='test-group'
                        )
    print("itera")
    for message in consumer:
        try:
            data = loads(message.value.decode('utf-8'))
            df = pd.DataFrame([data])
            print('{}'.format(df.head()))
        except Exception:
            print('no pudo leer')
            continue

while(True):
    try:
        run_consumer()
        print('break')
        break
    except Exception:
        print('asas')
        sleep(2)
# Out:
# itera
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-218b576ea442> in <module>
#      30 while(True):
#      31     try:
# ---> 32         run_consumer()
#      33         print('break')
#      34         break
#
# <ipython-input-28-218b576ea442> in run_consumer()
#      19                         )
#      20     print("itera")
# ---> 21     for message in consumer:
#      22         try:
#      23             data = loads(message.value.decode('utf-8'))
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     673             dict: Map of topic to list of records (may be empty).
#     674         """
# --> 675         self._coordinator.poll()
#     676
#     677         # Fetch positions if we have partitions we're subscribed to that we
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/coordinator/consumer.py in poll(self)
#     287                     self._client.poll(future=metadata_update)
#     288
# --> 289                 self.ensure_active_group()
#     290
#     291             self.poll_heartbeat()
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/coordinator/base.py in ensure_active_group(self)
#     405                     future = self.join_future
#     406
# --> 407                 self._client.poll(future=future)
#     408
#     409                 if future.succeeded():
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# ~/miniconda3/envs/ross/lib/python3.8/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %%
while(True):
    try:
        print('trrt')
        producer = KafkaProducer(
                                bootstrap_servers=[kafka_server],
                                value_serializer=lambda x: dumps(x).encode('utf-8')
                            )
        print('asaaa')
        break
    except Exception:
        print('not connected')
        continue

for index, row in all_data.iterrows():
    if(index%10==0):
        print("Producer has pushed {} messages".format(index))
    data = row.to_json()    
    producer.send(topic, value=data)
# Out:
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# not connected
# trrt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-94f37a873717> in <module>
#       2     try:
#       3         print('trrt')
# ----> 4         producer = KafkaProducer(
#       5                                 bootstrap_servers=[kafka_server],
#       6                                 value_serializer=lambda x: dumps(x).encode('utf-8')
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         self._metrics = Metrics(metric_config, reporters)
#     380
# --> 381         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     382                              wakeup_timeout_ms=self.config['max_block_ms'],
#     383                              **self.config)
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/client_async.py in __init__(self, **configs)
#     242         if self.config['api_version'] is None:
#     243             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 244             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     245
#     246     def _can_bootstrap(self):
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     907             try:
#     908                 remaining = end - time.time()
# --> 909                 version = conn.check_version(timeout=remaining, strict=strict, topics=list(self.config['bootstrap_topics_filter']))
#     910                 if version >= (0, 10, 0):
#     911                     # cache the api versions map if it's available (starting
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/conn.py in check_version(self, timeout, strict, topics)
#    1236
#    1237         for version, request in test_cases:
# -> 1238             if not self.connect_blocking(timeout_at - time.time()):
#    1239                 reset_override_configs()
#    1240                 raise Errors.NodeNotReadyError()
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/conn.py in connect_blocking(self, timeout)
#     338         while self._gai:
#     339             while time.time() < timeout:
# --> 340                 self.connect()
#     341                 if self.connected():
#     342                     if selector is not None:
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/conn.py in connect(self)
#     359     def connect(self):
#     360         """Attempt to connect and return ConnectionState"""
# --> 361         if self.state is ConnectionStates.DISCONNECTED and not self.blacked_out():
#     362             self.last_attempt = time.time()
#     363             next_lookup = self._next_afi_sockaddr()
#
# ~/miniconda3/envs/ross/lib/python3.8/site-packages/kafka/conn.py in blacked_out(self)
#     845         """
#     846         if self.state is ConnectionStates.DISCONNECTED:
# --> 847             if time.time() < self.last_attempt + self._reconnect_backoff:
#     848                 return True
#     849         return False
#
# KeyboardInterrupt:
